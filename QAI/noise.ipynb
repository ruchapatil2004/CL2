# %%
pip install qiskit-aer
# Out:
# Requirement already satisfied: qiskit-aer in c:\users\hp\qiskit_env_new\lib\site-packages (0.15.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit-aer) (1.2.4)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit-aer) (2.1.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit-aer) (1.14.1)
# Requirement already satisfied: psutil>=5 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit-aer) (6.1.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (1.13.3)
# Requirement already satisfied: dill>=0.3 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.3.0)
# Requirement already satisfied: typing-extensions in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\hp\qiskit_env_new\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\qiskit_env_new\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer) (1.3.0)

# %%
#Tackle Noise with Error Correction
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# %%
from qiskit_aer.noise import NoiseModel,depolarizing_error

# %%
qc=QuantumCircuit(3,3)

# %%
qc.h(0)
qc.cx(0,1)
qc.cx(0,2)
qc.measure([0,1,2],[0,1,2])

# %%
noise_model = NoiseModel()

# %%
# Add depolarizing noise for single-qubit gates and two-qubit gates
depol_1q = depolarizing_error(0.01, 1)
depol_2q = depolarizing_error(0.02, 2)
noise_model.add_all_qubit_quantum_error(depol_1q, ['u3', 'x', 'h'])
noise_model.add_all_qubit_quantum_error(depol_2q, ['cx'])

# %%
# Use AerSimulator and noise model for simulation
backend = AerSimulator()

# %%
# Execute the quantum circuit with noise model
result_with_noise = backend.run(qc,noise_model=noise_model, shots=1024).result()

# %%
# Get the raw counts with noise
noisy_counts = result_with_noise.get_counts(qc)

# %%
# Simple mitigation technique: scale counts based on expected noise
mitigated_counts = {key: noisy_counts[key] * (1 - 0.02) for key in noisy_counts}

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\qiskit_env_new\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\qiskit_env_new\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\qiskit_env_new\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Plot the mitigated results
plot_histogram(mitigated_counts)

# %%
print("Original counts:")
print(noisy_counts)
# Out:
# Original counts:
# {'000': 504, '111': 496, '101': 7, '010': 5, '011': 3, '110': 3, '100': 3, '001': 3}

# %%
print("Mitigated counts:")
print(mitigated_counts)
# Out:
# Mitigated counts:
# {'000': 493.92, '111': 486.08, '101': 6.859999999999999, '010': 4.9, '011': 2.94, '110': 2.94, '100': 2.94, '001': 2.94}

# %%
plot_histogram([noisy_counts, mitigated_counts], legend=['Original', 'Mitigated'])
